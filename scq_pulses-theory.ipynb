# %% [markdown]
# # Pulse Control and Reaout in Superconducting Qubits (Th)
# ### Mathematical description of superconducting qubit's driving and readout.

# %% [markdown]
# # Table of Contents
# * [Introduction to Superconducting Qubits](#chapter1)
# * [Qubit Thermalization](#chapter2)
#     * [Section 2.1](#section_2_1)
# * [Qubit Pulse Control](#chapter3)
#     * [Section 3.1](#section_3_1)
#         * [Sub Section 3.1.1](#sub_section_3_1_1)
# * [Qubit Readout](#chapter4)
# * [Accessing Higher Energy Levels on a Transmon](#chapter5)

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## 1.- Introduction to Superconducting Qubits <a class="anchor" id="chapter1"></a>

# %% [markdown]
# ## 2.- Qubit Thermalization <a class="anchor" id="chapter2"></a>

# %% [markdown]
# ## 3.- Qubit Pulse Control <a class="anchor" id="chapter3"></a>

# %% [markdown]
# ## 4.- Qubit Readout <a class="anchor" id="chapter4"></a>

# %% [markdown]
# ## 5.- Accessing Higher Energy Levels on a Transmon <a class="anchor" id="chapter5"></a>
