# %% [markdown]
# # 4. Two-qubit driving

# %% [markdown]
# ## 4.1. The CR and ECR gates

# %% [markdown]
# ## 5.2. Multi-qubit driving with OpenPulse

# %% [markdown]
# ## 5.3. ECR calibration example
